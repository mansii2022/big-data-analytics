# %% [markdown]
# <a href="https://colab.research.google.com/github/mansii2022/big-data-analytics/blob/main/Assignment5_feb28_202301034.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#question1
#part1
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv("company_sales_data.csv")
sns.lineplot(x="month_number", y="total_profit",data=df)
plt.title('total profit of all month')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#question1
#part2

import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv("company_sales_data.csv")

for column in df.columns:
    if column != "month_number":
        sns.lineplot(x="month_number", y=column, data=df)

plt.title('All Products Sales')

plt.show()

# %%
#question1
#part3

import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv("company_sales_data.csv")

for column in df.columns:
    if column != "month_number":
        plt.figure()
        sns.barplot(x=df["month_number"], y=df[column])
        plt.title(f"Bar plot for {column}")
        plt.show()

# %%
#question2

import plotly.express as px

# Generate some data
df = px.data.iris()

# Create the scatter plot
fig = px.scatter(df, x="sepal_width", y="sepal_length", color="species")

# Show the plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#question3
import plotly.express as px

# Generate some data
df = px.data.iris()

# Create the bar plot
fig = px.bar(df, x="sepal_width", y="sepal_length", color="species")

# Show the plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#question4
import plotly.express as px

# Generate some data
df = px.data.iris()

# Create the histogram plot
fig = px.histogram(df, x="sepal_width", y="sepal_length", color="species")

# Show the plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
