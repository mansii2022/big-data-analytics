# %% [markdown]
# <a href="https://colab.research.google.com/github/mansii2022/big-data-analytics/blob/main/Assignment4_14feb202301034.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt

df=pd.read_csv('company_sales_data.csv')
df
# Out:
#     month_number  facecream  facewash  toothpaste  bathingsoap  shampoo  \
# 0              1       2500      1500        5200         9200     1200
# 1              2       2630      1200        5100         6100     2100
# 2              3       2140      1340        4550         9550     3550
# 3              4       3400      1130        5870         8870     1870
# 4              5       3600      1740        4560         7760     1560
# 5              6       2760      1555        4890         7490     1890
# 6              7       2980      1120        4780         8980     1780
# 7              8       3700      1400        5860         9960     2860
# 8              9       3540      1780        6100         8100     2100
# 9             10       1990      1890        8300        10300     2300
# 10            11       2340      2100        7300        13300     2400
# 11            12       2900      1760        7400        14400     1800
#
# ...

# %%
#question1
plt.plot(df['month_number'])
plt.plot(df['total_profit'])

plt.title('Line Plot')
plt.xlabel('month')
plt.ylabel('profit')
plt.show()

# %%
#question2
plt.title('multiline plot')

x=['facecream','facewash','toothpaste','bathingsoap','shampoo','moisturizer']
plt.plot(df[x])
plt.ylabel('total unit sold')
plt.xlabel('month')
# Out:
# Text(0.5, 0, 'month')

# %%
import matplotlib.pyplot as plt
features = ['facecream','facewash','toothpaste','bathingsoap','shampoo','moisturizer']
values = [10000, 20000, 30000, 40000, 50000,60000]
plt.bar(features, values)
plt.title("Bar Chart of Features")
plt.xlabel("Features")
plt.ylabel("Values")
plt.xticks(rotation=45)
plt.show()
