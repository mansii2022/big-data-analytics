# %% [markdown]
# <a href="https://colab.research.google.com/github/mansii2022/big-data-analytics/blob/main/202301034_april16_assignment8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

x1 = np.array([5.3, 4.8, 2, 3, 4])
x2 = np.array([9.5, 11, 14, 8, 12])
y = np.array([127, 160, 150, 170, 140])

common_length = min(len(x1), len(x2), len(y))
numerator = 0
denominator = 0

for i in range(common_length):
    numerator += (x1[i] - x1_mean) * (y[i] - y_mean)
    denominator += (x1[i] - x1_mean) ** 2
b1 = numerator / denominator
b0 = y_mean - b1 * x1_mean

numerator = 0
denominator = 0

for i in range(common_length):
    numerator += (x2[i] - x2_mean) * (y[i] - y_mean)
    denominator += (x2[i] - x2_mean) ** 2
b2 = numerator / denominator
b0 = y_mean - b2 * x2_mean

print("b0:", b0)
print("b1:", b1)
print("b2:", b2)

plt.scatter(x1, y, color='blue')
plt.plot(x1, Y, color='red')
plt.xlabel('X1')
plt.ylabel('Y')
plt.title('Multiple Linear Regression')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# b0: 167.8066037735849
# b1: -5.92075892857143
# b2: -1.6886792452830182
