# %% [markdown]
# <a href="https://colab.research.google.com/github/mansii2022/big-data-analytics/blob/main/202301034_10april_assignment_7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
x = np.array([1, 2, 3, 4, 5])
y = np.array([2, 3, 5, 7, 11])

x_mean = np.mean(x)
y_mean = np.mean(y)
numerator = 0
denominator = 0

for i in range(len(x)):
    numerator += (x[i] - x_mean) * (y[i] - y_mean)
    denominator += (x[i] - x_mean) ** 2
b1 = numerator / denominator
b0 = y_mean - b1 * x_mean

print("Regression coefficient (B1):", b1)
print("Intercept (B0):", b0)
plt.scatter(x, y, color="blue")
plt.plot(x, b0 + b1 * x, color="red")
plt.xlabel(" (X)")
plt.ylabel(" (Y)")
plt.show()
# Out:
# Regression coefficient (B1): 2.2
# Intercept (B0): -1.0000000000000009
